# %% [markdown]
# # Homework 5
# You can use the space bellow to add all the modules you are importing (e.g., numpy), you can also do it throughtout the notebook, but it's easier to have it all in one place.

# %% [markdown]
# ## Problem 1 (15 points)
# Import numpy and matplotlib.pyplot (You can do that in the space above). Create a numpy array x that goes from 1 up to and including 100 (last element must be 100.0) with a step of 0.5.

# %% [markdown]
# Create array y that is the log10 of x and array z that is equal to the square root of x.

# %% [markdown]
# Plot y(x) and z(x) in the same plot. Manually specify different colors, line styles, line thicknesses, markers (and their size) and tickmarks for your plot. Add titles to your plot axis. Make sure they are legible. Save it as a pdf file using the appropriate naming conventions.

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2 (10 points)
# Create a numpy array q that has the values: 45, 24, 5 ,30 , 3, 67, 33, 60, 65, 13, 82, 75, 21, 77, 67, 8, 86, 62, 23, 70, 11, 70, 21, 15, 84, 51, 6, 79, 78, 66, 2, 93, 49, 74, 23, 85, 25, 38, 1, 89.

# %% [markdown]
# Print the array. Print the locations where q is larger than 50. Print, in one command, the elements of q that are larger than 50 and smaller than 70.

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# [45 24  5 30  3 67 33 60 65 13 82 75 21 77 67  8 86 62 23 70 11 70 21 15 <br>
#  84 51  6 79 78 66  2 93 49 74 23 85 25 38  1 89]<br>
# [ 5  7  8 10 11 13 14 16 17 19 21 24 25 27 28 29 31 33 35 39]<br>
# [67 60 65 67 62 51 66]<br>
# </span>

# %% [markdown]
# Make a list q_list out of q (remember that q is an array).

# %% [markdown]
# Print the 12th up to and including the 14th elements of the list q_list (remember that the first element has index 0).

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# [75, 21, 77]<br>
# </span>

# %% [markdown]
# Change element with index 28 of the list to be 42.0. Does it work? Are there any errors? Why/ why not? Explain in a comment inside the code.

# %% [markdown]
# Make a tuple q_tuple out of q. Print the 20th element of q_tuple.

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# 70
# </span>

# %% [markdown]
# Change element with index 21 of q_tuple to be 44.0. Does it work? Are there any errors? Why/ why not? Explain in a comment inside the code.

# %% [markdown]
# ## Problem 3 (10 points)
# Create a list of strings word_list that contains the words 'twinkle', 'twinkle', 'little', 'star'. Scan every word (one by one is fine, we haven’t talked about for loops yet) of your list and find out which words contain an 'e'. Also, find the index of the letter 'e' in the word, e.g., in 'late', 'e' is on 3 (if the letter is not in the word you should print -1).

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# The indexes of letter 'e' on the words are: <br>
# For the word twinkle : 6 <br>
# For the word twinkle : 6 <br>
# For the word little : 5 <br>
# For the word star : -1
# </span>

# %% [markdown]
# Do the same thing for the letter 'a'

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# The indexes of letter 'a' on the words are: <br>
# For the word twinkle : -1<br>
# For the word twinkle : -1<br>
# For the word little : -1 <br>
# For the word star : 2
# </span>

# %% [markdown]
# Create a function word_in_list(word, list_of_words) that returns true if the word is in the list, and false if it isn't.

# %% [markdown]
# Now check if the word 'star' and the word 'bright' are in word_list (check it separately!), and write an informative string that represents that.

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# Yes, 'star' is in word_list <br>
# No, 'bright' is not in word_list
# </span>

# %% [markdown]
# ## Problem 4 (15 points)
# Create a function word_to_number that takes as input an English word that corresponds to a number from 0 to 20 (‘zero’, ‘one’ etc) and returns the corresponding number (0, 1, etc). In the function create a dictionary that maps every appropriate English word to the corresponding number (so 1 will be mapped to ‘one’ ). The keys should be your words and the values the number. Remember to write an appropriate docstring for your function!

# %% [markdown]
# Now call the function for: ‘three’, ‘seven’, ‘twelve’ , ‘sixteen’ and ‘nineteen’ and print an informative statements.

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# Three is: 3<br>
# Seven is: 7<br>
# Twelve is: 12<br>
# Sixteen is: 16 <br>
# Nineteen is: 19
# </span>

# %% [markdown]
# # Log goes here $\downarrow$
