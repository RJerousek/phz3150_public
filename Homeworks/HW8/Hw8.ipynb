# %% [markdown]
# # Homework 8
# You can use the space bellow to add all the modules you are importing (e.g., numpy), you can also do it throughtout the notebook, but it's easier to have it all in one place.

# %% [markdown]
# ## Problem 1 (30 points)
# You are in the committee for organizing your town's triathlon and you need to have an estimate for how long the event will take , and who might win and who might lose.

# %% [markdown]
# ### a) (5 points)
# Create a numpy array **sports** with the distance per sport (swimming, cycling, and running): 1500, 40000, 10000 [meters].
#
# Also create another numpy array **athletes_times** that contains the information about each participant's average speed per sport, given in the table below. (You should have a (6, 4) array)
#
# | ID  | Avg. swimming speeds (m/s) | Avg. cycling speend (m/s) | Avg. running speed (m/s) |
# | -------- | ------- | ----------| ------------ |
# | 1 | 1.204 | 6.6 | 0.32 |
# | 2 | 1.212 | 6.5 | 0.36 |
# | 3 | 1.14 | 6.6 | 0.38 |
# | 4 | 1.12 | 6.2 | 0.38 |
# | 5 | 1.24 | 5.6 | 0.4 |
# | 6 | 1.201 | 6 | 0.3 |

# %% [markdown]
# ### Solution:
# sports =  $$\begin{bmatrix} 1500 & 40000 & 10000 \end{bmatrix}$$
#
#
# athletes_times =
# $$
# \begin{bmatrix}
# 1.  &  1.204 & 6.6 &  0.32 \\
# 2.  &  1.212 & 6.5 &  0.36  \\
# 3.  &  1.14  & 6.6 &  0.38 \\
# 4.  &  1.12  & 6.2 &  0.38 \\
# 5.  &  1.24  & 5.6 &  0.4  \\
# 6.  &  1.201 & 6.  &  0.3
# \end{bmatrix}
# $$

# %% [markdown]
# ### b) (10 points)
# Create a function **triathlon_times(sports, athletes_times)** that gets as input your two arrays and returns which participant will finish first (their ID number), their expected time in hours, and which one will finish last, and their time in hours. (Make sure the function returns in this specific order, and note that it will not return a tuple or a list!)

# %% [markdown]
# Call the function and store the returned values in the following variables: **first_ID, first_time, last_ID, last_time**. Print those variables in an informative way and check to see if your result makes sense (you should check with a calculator).

# %% [markdown]
# ### Solution:
# function returns:
# ```
# first_ID = 5
#
# first_time = 9.26
#
# last_ID = 6
#
# last_time = 11.46
# ```
#
# informative print statement:
#
# `Atlhete 5 will finish first with a time of 9.26 hours.`
#
# `Atlhete 6 will finish last with a time of: 11.46 hours.`

# %% [markdown]
# ### c) (4 points)
# Create a dictionary **sports_dict** with keywords of the sports, i.e., 'swimming', 'cycling', and 'running'; and values with the total distance for each sport. Also create a dictionary **athletes_times_dict** with the IDs being the keywords, and a list with the average speeds being the values.

# %% [markdown]
# ### d) (8 points)
# Create a function **triathlon_times_dict(sports_dict, athletes_times_dict)** that does the same thing as the function you created before, but now uses the dictionaries.

# %% [markdown]
# Call the function and store the returned values in the following variables: **first_dict_ID, first_dict_time, last_dict_ID, last_dict_time**. Print those variables in an informative way and check to see if your result makes sense and if they match what you got before.

# %% [markdown]
# ### Solution:
#
# Informative print statements:
#
# `Paul will finish first with a time of: 9.26  hours.`
#
# `Lionel will finish last with a time of: 11.46 hours.`

# %% [markdown]
# ## Problem 2 (10 points)
# You need to build an electric circuit with N resistors. What will the properties of the circuit be if we connect the resistors in series or in parallel?
#
# Create a function **my_circuit(sys_info, resistances, IV)** that takes as input:
# 1. A string (sys_info) with information on whether your circuit is in series or parallel, i.e., this parameter should be 'series' or 'parallel';
# 2. A numpy array (resistances) with their individual resistances;
# 3. The voltage (V) or amperage (I) (IV) of the circuit (depending on if it is in series or parallel). [Make sure to return it in that order!]
#
# The function should return the total resistance of the system, and the total voltage (for a circuit in series) or total amperage (for a circuit in parallel).
#
# Remember that for a circuit in series, the total resitance is $$R_\text{tot} = \sum_i R_i$$, and for a circuit in parallel $$\frac{1}{R_\text{tot}} = \sum_i \frac{1}{R_i}$$ For a circuit in series, I is the same through each resitor, and in parallel V is the same across each resistor. Also remember Ohm's law: $R = V/I$.

# %% [markdown]
# Now call the function and print an informative string for each scenario:
#
# * A circuit in series with 3 resistors with resistances of 5 $\Omega$, 2 $\Omega$, and 7 $\Omega$, and a current of 10 A.
# * A circuit in parallel with 3 resistors with resistances of 12 $\Omega$, 5 $\Omega$, and 20 $\Omega$ and a voltage of 15 V.

# %% [markdown]
# ### Solution:
#
# Informative print statements:
#
# `The total resistance of your circuit in series is  14.0  and has a total voltage of  140.0 for a current of 10 A.`
#
# `The total resistance of your circuit in parallel is  3.0  and has a total amperage of  5.0 for a voltage of  5.0 V.`

# %% [markdown]
# ## Problem 3 (15 points)
# A piston has a volume $V$ containing dry air (an ideal gas) with pressure $P$ and temperature $T$. Under the ideal gas law $$\frac{PV}{T} = \text{constant}$$ The constant is $nk_B$ where $n$ is the number of molecules and $k_B$ is the Boltzmann's constant. Under adiabatic expansion, where no heat is added or removed, $$PV^\gamma = \text{constant}$$ where the ratio of heat capacities $\gamma = c_p/c_v = 1.4$ for diatomic gases, like N$_2$ and O$_2$, which dry air is mostly consisted of.
#
# ### a) (8 points)
# Create a function **piston(V, P0, V0, T0, gamma)** that takes as input:
# 1. An array of N volumes (V)
# 2. And initial values (P0, V0, T0, gamma)
#
# The function should then calculate the pressures for the different volumues V using the adiabatic law, and calculate the temperatures using the ideal gas law. The function will return an (N, 3) array containing the (P, V, T) values.

# %% [markdown]
# Call the function for the following values and store the results in **data**

# %%
V = np.linspace(1, 0.1, 100)
P0 = 1
V0 = 1
T0 = 300
gamma = 1.4

# %% [markdown]
# ### b) (7 points)
# Make a 3D plot of your (P, V, T) data as a curve in space. Be sure to include labels with units on each axis and a title.

# %% [markdown]
# ### Solution:
#
# Your plot should look something like this:
# ![plot.png](attachment:ce59b3ac-c9a0-46b9-9565-f7957caccf93.png)

# %% [markdown]
# # Log goes here $\downarrow$ (Make sure that you change the cell to be a markdown cell!!!)
