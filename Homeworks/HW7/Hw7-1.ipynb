# %% [markdown]
# # Homework 7
# In the early 17th century Kepler used observations of the motions of planets in our Solar System to derive his now famous laws of planetary motion. According to these laws, all planets in our Solar system move around in elliptical orbits with the Sun in one focus (1st law), their speed varies along the orbit with the further they are from the Sun the slower they move (2nd law) and their orbits are such that the square of their period is proportional to the cube of their (average) distance to the Sun (3rd law).
#
# ## Probrem 1  (15 points)
# Here you will test the validity of the 3rd law to planets of our Solar system. Write a function called *kepler_3rd(period)* that gets as input the orbital period of a planet in years and returns the orbital distance of a planet to the Sun in AU (1 Astronomical Unit ~150,000,000km or 92,967,000 miles). This function should use the simple approximation for the 3rd law:
# $$
# P^2 \propto \alpha^3
# $$
# since it will focus on planets of our Solar system. From Kepler’s 3rd law $P^2/\alpha^3$ = constant, so you can deduce that
# $$
# \frac{P_1^2}{P_2^2} = \frac{\alpha_1^3}{\alpha_2^3}
# $$
# for any solar system.
#
# Use this equation in your function, and write an appropriate docstring.

# %% [markdown]
# Now, use the $(P,\alpha)$ properties of our Earth as the reference point (i.e. $P_1,\alpha_1$). Remember that the period of our Earth is 1 year or 365.25 days and $a_\text{orb}$ = 1 AU. Using the function you just created, calculate the distances of the other planets of our Solar system using the observed periods from the following table:
# |Planet | Period (Earth Days)|
# |:- | :- |
# |Mercury | 87.96|
# |Venus | 224.7|
# |Mars | 686.97|
# |Jupiter | 4332.82|
# |Saturn | 10775.6|
# |Uranus | 30687.15|
# |Neptune | 60190.03|

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# Mercury is 0.38707637398311073 AU away from the sun.<br>
# Venus is 0.7233390285130801 AU away from the sun.<br>
# Mars is 1.5236961311031048 AU away from the sun.<br>
# Jupiter is 5.201400341240987 AU away from the sun.<br>
# Saturn is 9.547745291596849 AU away from the sun.<br>
# Uranus is 19.1827509207773 AU away from the sun.<br>
# Neptune is 30.057733077422224 AU away from the sun.
# </span>

# %% [markdown]
# How do the values you get compare to the actual distances of the planets (0.4 AU ; 0.7 AU ; 1.524 AU ; 5.2 AU ; 9.6 AU ; 19.2 AU and 30.1AU)? Store the actual distances in a list *dist_actual*, and the distance you calculated in a list *dist_calc*. Make a plot that compares the real distances with the ones you retrieve from Kepler's law. Make sure you specify manually different symbols and colors for the two sets (predicted and real distances). Use the names of the planets as tick labels on the x axis.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Problem 2 (15 points)
# Graduation season is coming, and you need to buy presents for all your friends graduating! Surprising your friends with many little presents which you hide in one big box is more fun than getting them one big present. The logistics though, are hard. To prepare for that, you need to find out how much wrapping paper you will need for the boxes and how many presents you can fit in every box! Create a **class** called *graduation_presents* that uses the dimensions a,b,c (in inches) of a box to calculate the box’s surface area and volume. Assume that your dimensions are in inches. The class should also know how many presents you want to fit in your box and how much wrapping paper you have (in inches$^2$). Use a proper initiation function.
#
# Your class should contain:
# 1. An initiation function
# 2. A function **surface_area** that returns the surface area of your box.
# 3. A function **volume** that returns the volume of your box.
# 4. A function **enough_paper** that checks if you have enough wrapping paper to cover your box.
# 5. A function **fits** that checks if your box can fit all the presents (assuming that the average volume of a gift is 25 inches$^3$.
# 6. A function **print_gift** that combines all this information and returns a string if you have enough wrapping paper to wrap your box, if your gifts fit in the box, or if nothing is right. (Examples given below for each case. Make sure your strings match perfectly what the examples are, otherwise you will get points taken off).

# %% [markdown]
# Test it for the following combinations:
# | a | b | c | number of gifts | wrapping paper available |
# | - | - | - | - | - |
# | 10 | 10 | 10 | 15 | 800 |
# | 10 | 10 | 10 | 55 | 1000 |
# | 100 | 20 | 10 | 55 | 300 |
# | 10 | 10 | 10 | 1000 | 50 |

# %% [markdown]
# <span style="color:red;">
# <h1> Solution:</h1>
# Yes, you have enough wrapping paper for the box, and all your presents fit!<br>
# Oops! enough paper but not enough space for all the presents.<br>
# Sorry, you don't have enough paper for the box, but at least all your presents fit!<br>
# Oops! not enough paper and not enough space.
# </span>
