# %% [markdown]
# # PHZ 3150 Final Project.
# Due before the final exam period. If you decide to take the 90 question final exam instead, do not turn in this final project and simply take the final exam during the final examination period. Otherwise, submit this assignment. I will grade *only* one: Final Exam OR Final Project.

# %% [markdown]
# ### You work for one of the most distinguished private investigator agencies in the world, PIa$^2$. An email arrives asking for your help:
#
# ```
# From: president_of_the_world@mail.com
# To: best_PI_in_the_world@mail.com
# Subject: SOS! College students in Danger of Massive Amounts of Homework!
#
# To whom it may concern,
#     I've been told that your agency has the best investigators in the world and we have reason to believe
# that Dr. H.W. Monster is releasing a computer virus worldwide to give every college student homework over the break!
#
# We need you to gain access to their system and cancel their plans! Please meet me as soon as possible at the following lat. and lon. coordinates: 60.424489, -64.634374.
#
# Sincerely,
#     Shrek.
#     (President of the world)

# %% [markdown]
# You book the first ticket to the North of Canada and drive to the far north. The place is desolate and icy. In front of you there is a weird looking cave. You get out of the car and approach the entrance of the cave. Before you know it there is noise behind you and evil Dr. Cane and helpers are charging toward you with their bear cavalry. You get arrested and thrown in a dungeon deep in the cave.

# %% [markdown]
# ### A grainy old CRT computer monitor lights up and a video starts playing. *Dr. H.W. Monster* appears on the screen laughing their evil laugh. There is a keyboard in front of you and the screen is asking for input.

# %%
yourname = input('Please give me your name: ')
# Out:
# Please give me your name:  Richard

# %%
##Run this:

from IPython.display import Markdown, display

# Display the Markdown text with the variable
display(Markdown(f"## *Welcome to my oubliette, {yourname}*:"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from IPython.display import Markdown, display
#       5 # Display the Markdown text with the variable
# ----> 6 display(Markdown(f"## *Welcome to my oubliette, {yourname}*:"))
#
# NameError: name 'yourname' is not defined

# %% [markdown]
# Do you really think that you can save college students from me??? Dr. Monster? Muahahaha!
# I am soooo confident that you will fail to stop me that I even left some hints for you around the room!
# They *could* help you escape and reach the server that will release my homework virus world wide
# but you will never make it on time! Muahahaha!
# I will release the homework virus in two weeks!
# I hope you like swimming in homework! Muahahaha!

# %% [markdown]
# ## 1. *Looking for a way out*: (2 points)

# %% [markdown]
# Let's save college together. To escape from this room you will need to use all the coding skills you've learned this semester.
# 1.  Start your log please and track how much time you spend on this assignment.
# 2. You will also need to import the necesary packages to do numerical
# calculations, curve-fitting, integrals, open pickles, and plot to 2d and 3d figures. Start by doing all your imports here.
# 4. You also need to create an empty list named `key_code` that you will slowly populate with the keys you get as you solve the puzzles.

# %%
#import your modules here:

# %%
#assign a list for your keycode:

# %% [markdown]
# Let's find our way out of here!

# %% [markdown]
# ### Take a look around the dungeon.
#
# ![DALL·E 2024-10-21 18.07.53 - A large room with a loft. The room features a prison door with a digital keypad mounted beside it. In one corner, an old desk holds a dusty CRT monito.webp](attachment:cae79a31-1c44-4c46-8728-5cf36e58a2c4.webp)
#
# At the other side you see the door. Next to it there is something that looks like a key pad. The hints that Dr. Monster left all around the room *might* help you get code and escape out of this room...
#
# Desks, books, paintings, chests, chairs are all over the place. This room is so full of possible hiding places. Where to start?

# %% [markdown]
# ## 2. *The encrypted note:* (8 points)

# %% [markdown]
# Walking across the dungeon you notice a weird looking painting. It smells of fresh paint. Dr. Monster must have just painted this for some reason! You take a closer look. It depicts the dungeon you are in, but it looks slightly different: there is a number "2" on the table in front of you in the painting. There is an open book on table in front of the painting. The open page contains weird sequences of numbers:
# This is what is written in the book:
#
# 20 9 3 11  20 15 3 11 20 9 3 11  20 15 3 11 20 9 13 5 9  19 18 21 14 14 9 14 9 7  15 21 20
#
# What could this mean? You suddenly realize it's a code.
#
# 1. Make a list `message` that contains all the numbers on the note.
# 2. Write a dictionary `letters_to_numbers` that has as keys letters of the alphabet and as values numbers 1 to 26.
# 3. Write a function that loops over the numbers in the book and uses the dictionary to decode the message.
# 4. Print the message out.

# %%
#2.

# %% [markdown]
# ## 3. *Cuckoo!:* (8 points)

# %% [markdown]
# Just as you decode the message a cuckoo clock goes off three times somewhere in the room. The time is ticking indeed....You walk toward the clock. It looks old, and has a big mirror at the bottom part. The cuckoo wears glasses?!?! You look around and notice a pair of glasses on the floor that looks exactly like the one the cuckoo wears. Can it be part of the solution? You put the glasses on and look at the clock. There is a secret message painted on the mirror of the clock!
#
# 1. Use your favorite *numpy* routine to read in the data from 'the_clock_mirror.dat'
# 2. Make a contour plot using contouring levels 0, 1, 2.
# 3. Give the plot axis labels, a title, and ticks with readable font sizes. Rotate all of the tick labels by 45$^\circ$ and label the x and y axes using latex. x: $\chi_{axis}$ and y: $y^{axis}$
#
#    Make the title `yourname` +  "'s Clue" where `yourname` is a variable containing your first name.
# 5. Populate your *key_code* with the number you see on the mirror and print the *key_code*.

# %%
#3.

# %% [markdown]
# ## 4. *Now what?:* (6 points)

# %% [markdown]
# You got the first number! However, you have no idea where to look next...did you miss something? You put on the glasses again and look around. On the opposite wall you see another hidden message written.

# %% [markdown]
# 1. Read the data from 'the_secret_message.dat'.
# 2. Make a contour plot using contouring levels 0, 1, 2 and 3.
# 3. The message is flipped. Use the appropriate plt command to flip the y-axis.

# %%
#4.

# %% [markdown]
# ## 5. *What's in the Box?*: (10 points)
# You look up to find a chain hanging from the ceiling with a ball on it. On the ball is an arrow that points up the stairs of to the loft! There is a big open briefcase in the loft. You go running to the ladder and climb it. You approach the chest and open it. It is full of torn pages from a book. You remove them from the box and see a picture of Dr. Monster laughing his evil laughter. Interestingly, the first page has a hand-written 'muahaha' at the top. Can this be the next clue? I wonder what is on the last page of the book...

# %% [markdown]
# ![DALL·E 2024-10-21 20.56.50 - An open book with the word 'MuaHaHa' scribbled maniacally over its pages in chaotic, exaggerated handwriting. The lettering is bold and erratic, givin.webp](attachment:e8d29c46-46bf-4ca3-bfa5-05e95efb262a.webp)

# %% [markdown]
# 1. Write a code that reads the_torn_book.dat line by line...
# 2. and counts how many many times the word 'muahaha' appears in it in any case and even possibly embedded in another word.
# 3. it should also count the total number of words in all of the lines that contain 'mauhaha's.
# 4. The code should then print an informative statement to let you know how many sinister laughs it found, how many  lines containing sinister laughs it found, and how many total words it counted.
# 5. **The difference between the *number of sinister laughs* and the *number of lines containing sinister laughs* is  number you need for the key pad.** Populate your *key_code* and print the current *key_code* out!

# %%
#5.

# %% [markdown]
# ## 6. *There's More to this Story...* (10 points)

# %% [markdown]
# ### Dr. Monster left you a message on the last line of the book about a *Secret Clue*.
# 1. Adapt your previous code to find it and print it out.

# %% [markdown]
# ### You look at the book contents and suddenly it all makes sense!
#
# The text is full of numbers. You just need to find the number of times each number ('one', 'two', 'three' and 'seven') appears and then use the equation Dr. Monster gave you to calculate the next key.
#
# 2. Make a code that reads all the book and counts how many 'one's, 'two's,'three's and 'seven's the book has (4 points).
# 3. Use these sums in the riddle Dr. Monster gave you.
# 4. The integer part is the next number you need for the key pad.
# 5. Populate your *key_code* with this number and print it out.

# %%
#6.

# %% [markdown]
# ## 7. *Holo world!*: (8 points)

# %% [markdown]
# ### At the bottom of the chest there is a little holographic machine with a big red button. You can't help yourself and you press it.
#
# You hear Dr. Monster's voice come out of a small speaker in the device:
#
# "Muahaha! You fool! You just couldn't help yourself but to press the red button! Now you have twice as many tasks to complete because I just extended the keycode! You'll never get out in time!"
#
# Their voice trails off but you here them say "...even if the get out, they'll never get the password to stop the homework virus right, Meowser? Let's check on that virus... input password, umm what was it now? Oh yes!... `Meowser = q*t*pi` ..."
#
# Apparently, they forgot to stop recording!
#
# ![DALL·E 2024-10-21 20.43.47 - An open treasure chest containing a copy of 'Around the World in Eighty Days' placed beside a small holographic machine with a large red button. The h.webp](attachment:ba531ea6-3f49-4e81-8d68-36f9077e4a60.webp)

# %% [markdown]
# There is a hologram produced by the device. To see it, you need to plot it in 3D.
#
# This ***must*** be the clue about where to look next.
#
# 1. Read data from file `hologram.dat` and assign the three columns to variables x1, y1, z1 .
# 2. Make a 3D scatter plot with your x1,y1,z1 data.
# 3. Save the 3D plot with an appropriate name.
# 4. What does it look like? (This is your next clue) Print an informative statement with your one word answer.

# %%
#7.

# %% [markdown]
# ## 8. *The Matrix*: (8 points)

# %% [markdown]
# You look around the room for weather related artifacts...As you wander around the room you notice a sketch of Vermeer's *Girl with the Pearl Earring* on tracing paper over the original painting...
#
# ![DALL·E 2024-10-21 21.25.31 - A traced sketch of Vermeer's 'Girl with the Pearl Earring,' featuring a tornado in the background. The sketch has a rough, hand-drawn feel, with the g.webp](attachment:396bfae5-a122-49be-86b2-9bb19da2e4a1.webp)
#
# Can this be it? You turn over the tracing paper with the sketch on it and find a matrix with each number written sideways inside the matrix brackets on the back of the trace. What could we possibly have to do with it?

# %%
matrix = np.array((\
 [[ 3.51061955, -0.30931513, -0.20039041, -1.84967189,  3.37961666, -2.87480747],
 [ 0.61782433,  2.48216769, -0.21270267, -0.74511832,  2.59254313, -2.05896767],
 [ 3.68527934, -6.15561797,  3.57663256, -6.46917942,  9.79073889, -5.31487302],
 [ 3.36502167, -5.42126547,  0.41269832, -2.76551826,  9.10361759, -5.11655629],
 [ 2.73504493, -4.55046753,  0.38470395, -4.86679398, 11.42609506, -5.02470205],
 [ 1.02045903, -1.81653286,  0.2693638,  -3.75961843,  4.73877235, -0.22999659]]))

# %% [markdown]
# ### The puzzle:
# 1. Use numpy to find the *trace* of the matrix. Print an informative statement explaining how the trace of a matrix is found and what the numerical value of the trace of this matrix is.
# 2. Use the *linalg* library in *numpy* to find the *eigenvalues* of the matrix. You don't need to know what *eigenvalues* are, but if you don't you will definitely learn all about them in a future physics or math course! Figure out how to find them with numpy. Print an informative statement stating how many eigenvalues the matrix has and what there sum is.
# 3. Use the appropriate numpy function to calculate the *determinant* of the matrix and divide it by the trace.
# 4. The original of *this painting* was painted in what year? Google it! Sum the numbers of the year up. (so if was painted in 1111 the answer is 1 + 1+1 +1 = 4) (1 point)
#
# Set the variable $u$ equal to the number of parts 1 - 4 that have the same answer (within 4 digits passed the decimal point).

# %%
#8.

# %% [markdown]
# ## 9. *E.T. looking for Earth*: (8 points)
#
# You also find a copy of Carl Sagan's *Pale Blue Dot*. Inside is a folded piece of paper with an example problem from a Planetary Science class. The scribblings on the page suggest that  Dr. H.W. Monster struggled to solve it.
#
# ![fd55f6fafd8f42f17690081960005fed.jpg](attachment:6f0a1b83-5b71-4633-b14e-eb6b90a61e12.jpg)

# %% [markdown]
# The example problem says:
#
# An extraterrestial octocat on the exoplanet Proxima Centauri *b* looks toward our Sun with their telescope and records a transit (a planet crosses in front of the Sun disk). The planet caused a dip in the total Sunlight the alien saw of $\Delta$f=0.007456. The event repeated after 10,740 days. Using Doppler spectroscopy the alien found that the planet causes the Sun to wobble with a velocity semi-amplitude of 2.76 m/s. Which planet did the alien detect? If Mercury is 1, Venus is 2,... then this planet is N.
#
# 1. Find the Radius and Mass of the planet using the information from above and these tips:
#       - Tip for the transit: you know that $\Delta$f $\sim \frac{R^2_{planet}}{R^2_{star}}$. Use this to find the radius of the planet in km, if you know that the Sun has a radius of 696,000km
#       - Tip for the wobbling: you know that the velocity semi-amplitude is given by:
#
#          $K = \frac{28.43 [\mathrm{m/s}]}{\sqrt{1-e^2}} \frac{m_{planet}\sin i}{m_{Jupiter}}(\frac{m_{planet}+M_{Sun}}{m_{Sun}})^{-2/3} (\frac{P}{1 year})^{-1/3}$.
#
#       - Use this to find the mass, $m_{planet}$ of the planet. You can assume that the orbit is circular so $e = 0$ and in the same plane as the Sun and alien observer so $\sin(i) = 1$. Also, note that $m_{planet} << M_{Sun}$
#
# 2. Now that you now the *Radius*, *Mass* and *Period* of the planet, write a function to compare to the data in this NASA database: https://nssdc.gsfc.nasa.gov/planetary/factsheet/ Print which planet did the extraterrestrial saw.
# 3. What is the number $N$ of the planet (if Mercury= 1, Venus = 2, Earth = 3, etc.)? Print an informative statement.
#         ***Remember:*** the Moon is *not* a planet and we are also not considering dwarf planets!
#
#
# ### The next key:
# 4. What is the number that is equal to $N/u$ where $u$ is from problem 7 and $N$ is from this problem (problem 8) ? Populate your *key_code* with the number and print the *key_code*

# %%
#9

# %% [markdown]
# On the back of the Carl Sagan book, there is a picture of an old computer that looks remarkably similar to the one in the room.

# %% [markdown]
# ## 10. *The bug exterminator*: (9 points)

# %% [markdown]
# On the other side of the room you see a chair in front of a computer. The chair has an 8 scratched on it. This must be where the next clue lies. You walk to the chair and look at the computer screen. There is some code, but it is full of bugs. Does Dr. Monster think that this can stop you?
#
# 1. Debug the code and make sure it runs without errors.
#
# 2. Run the code for:
#     - wheel of radii: $r_1 = 0.3$ m , $r_2 = 0.5$ m
#     - times the cars moved: $t_1 = 3$ s, $t_2 = 2$ s
#     - wheel initial angular speeds of $\omega_1 = 50$ rpm (revolutions per second) and $\omega_2 = 360$ rpm.
#     - car tangential (straight-line) constant accelerations of $a_1 = 3.00 \mathrm{m/s^2}$ and $a_2 = -1.00 \mathrm{m/s^2}$
#
# 3. **The second digit of the distance that the code returns is the next part of the key.** Append it to your key and print it.

# %%
def HWMonsters_buggy_func(rad1 = None, rad2 = None,t1 = None,t2 = None,omega1 = None,omega2 = None,\
                             a1 = None, a2 = None):
    # Docstring: Code that calculates the distance traveled by a car knowing the radius of its tires,
    # the time in seconds the car travels for, and the angular speed of the wheels in revolutions per minute (RPM),
    # and the tangential (straight line) constant acceleration of the car in m/s^2.
    #The function then compares the distance travelled by two cars and returns the speed of
    #the car that moved the furthest. The wheels are considered to roll without slipping.
    #The code puts the various quantities into arrays of the form: [Qty_car1,Qty_car2] 
    #before doing calculations.

    # Ask the user for the two radii of the car wheels:
    if rad1 is None:
        rad1 = float(input( 'Enter the 1st wheel radius in m:'))
    if rad2 is None:
        rad1 = float(input( 'Enter the 2nd wheel radius in m:' )) 
        
    radii = np.array([rad1,rad2])
    # Ask the user to input time intervals:
    
    if t1 is None:
        time1 = float(input( 'Enter the time for car 1 in s:' )) 
    if t2 is None:
        
    time2 = float(input( 'Enter the time for car 2 in s:' )) 

    times = np.arange(t1,t2)
    
    # Ask the user for the angular speed in RPM:
    
    if Omega1 is None:                                    
        Omega1 = float(input( 'Enter the initial angular speed of car 1 in RPM at t = 0:' ))
    if Omega2 is None:                                    
        Omega2 = float(input( 'Enter the initial angular speed of car 2 in RPM at t = 0:' ))
        
    omegas = np.array([omega1,omega2])
    
    # Ask the user for the car's straight line accelerations in m/s^2:

    if a1 is None:                                    
        a1 = float(input('Enter the straight-line acceleration of car 1 in m/s^2:' ))
    elif a2 is None:                                   
        a2 = float(input('Enter the straight-line acceleration of car 2 in m/s^2:' ))

    accels = np.array([a1,a2])
    alphas = accels/radii
    
    thetas = omegas*times + 0.5*accels*times^2
    dist = thetas*radii

    if dist[0] != dist[1]:
        print(f"Both cars travelled the same distance {dist[0]:.2f} m!") 
    else:
        index = np.argmax(dist) 
        print(f"Car {index} travelled the furthest with a final distance of {dist[1]:.2f} m.")
        return dist[0]
# Out:
#   Cell In[189], line 24
#     time2 = float(input( 'Enter the time for car 2 in s:' ))
#     ^
# IndentationError: expected an indented block after 'if' statement on line 22

# %%
#10.

# %% [markdown]
# ## 11. *Dungeons, Dragons, and Monte Carlo*: (8 points)
#
# Just as you were about to get up from the old computer you accidently kick something on the floor. It turns out to be a couple of dice for a role playing game. There is a 20 sided die and a 12 sided die.
# - You need to find the range of numbers that you can that you will get with equal probability when adding the number rolled on the 12 sided die to the number rolled on the 20 sided die.
# 1. Make a class `Dice` that initializes with the number of sides on the dice.
#       - Your class should have a method `roll()` that calls the function `random.randomit()` to "roll" the die.
#       - Your class should overload the `+` operation so that it represents rolling both dice simultaneously
# 2. Call your class methods 1 million times and store the results in an array.
# 3. Make a histogram and determine which scores from the sum of the 2 dice are equally likely.
#
# 4. **The difference between the top most and bottom most equally likely scores from the sum of the 2 dice is the next number in the key** Append this number to your key_code and print the key.
#
# *Hint: There is also an easy way to test your result with absolute certainty instead of Monte Carlo. Try to find it!*

# %%
#11.

# %% [markdown]
# ## 12. *Survival of the Fit-Test*: (9 points)
#
# ### Part A. *The data*.
# Looking across the room you see a painting with the an "X" written in the corner. Next to it, taped to the frame is a little green usb drive shaped like a little pickle. This must be the next thing to look at. You plug the drive into the computer There is a single file pickle file with GPS data: times, distances from some unknown location and GPS uncertainties in those distances (GPS error).
#
# 1. Read the arrays named `gps_time`, `gps_distance` and `gps_error` from `gps_data.pkl`.
# 2. Plot the distance of the object as a function of time making a publication-ready plot *with errorbars*, axis labels and plot title.
# 3. Use the appropriate python command to store the plot in a pdf.

# %% [markdown]
# ### Part B. *The model*:
#
# 4. Use the data to fit 2 models:
#
#    - One of the form $x(t) = v_0 * t + x_0$ where v_0 and x_0 are free parameters to be determined by fitting the model
#
#    - The other model is of the form $x(t) = \frac{1}{2} * a * t^2 + v_0 * t + x_0$
#
#     - Goal: find which best describes the data and why?
#
#     - **Write your own fitting code, do not use *scipy.optimize.curve_fit*** of course, you can use *curve_fit* to check your work!!
#
#     - **TIP:** limit your scan of the $v_0$ parameter in the 0.1 to 150 space for the first model with a step of 2; and the $a$ in the -10 to +10 with a step of 0.1 and u0 in the 0.1 to 140 with a step of 10 for the second model. For both models limit the space of the $x_0$ parameter to 1100 to 1400 with a step of 20.
#
# 5. Print: What are the speeds $v_0$ and acceleration $a$ of the best-fit model for both models?
#
# 6. Plot the best fitting constant velocity and constant acceleration models over the data.
#
# 7. Print: What is value of the *reduced* $\chi^2$ for the best-fit constant velocity and constant acceleration models?
#
# 8. Print: Is the object moving with a constant speed, or accelerating?
#
# 9. Populate your *key_code* with the first digit of the *magnitude* of your best-fitting acceleration in your best-fitting model and print the *key_code*.

# %%
#12.

# %% [markdown]
# ## 13. *The pendulum swings*: (10 points)

# %% [markdown]
# ### You are getting close to the end...
# You look at the clock as the minute hand moves to 10:50 pm. Suddenly an arm at the top of the chain holding the ball from parts 4 and 5 swings out bringing the top of the chain under the center of the skylight. The ball is swinging quite wildly with an initial maximum
# angle of $\theta \sim 60^\circ$. A note falls from above with a small piece of chalk attached.
#
# The note says:
#
# ```
# How many swings till the bird sings?
# -Dr. Monster
# ```
#
# You surmize from the note that you need to figure out how many periods the pendulum swings through before the cuckoo clock strikes 11:00. As the ball swings back and forth you notice a small "XI" reflected on the wall and moving back and forth.
#
# You grab a broken piece of chalk from the floor and try to start marking the position on the wall with a number every time the the clock ticks:
#
# $\theta(0 s) = 60^{\circ}$, $\theta(1 s) = 3^{\circ}$, $\theta(2 s) = -58^{\circ}$, $\theta(3 s) = 0^{\circ}$,...
#
#
# Suddenly the chain breaks at the top and the whole pendulum falls to the ground! I bet even H.W. Monster didn't even account for this. How are you going to get out now?
#
#
# You feel a bump on your head but you can't remember how it got there and for some reason, you can't remember anything about simple harmonic motion. Oh know. Even Dr. H.W. Monster probably didn't expect the chain to break. Are you stuck here forever??
#
# Fortunately, you do remember conservation of mechanical energy
#
# - You are also able to use the floor boards to measure the length of the pendulum to be $l =  3.45$ m.
#
# - You start frantically scribbling equations on a piece of paper:
#
#     $\Delta KE + \Delta U = 0 = \frac{1}{2} m v^2 - mg\Delta y$
#
#     $\frac{1}{2} m v^2 = mg\Delta y \rightarrow v = \sqrt{2g \Delta y}$
#
#     $\omega = \frac{d \theta}{dt} = \frac{v}{r} = \frac{\sqrt{2g \Delta y}}{l}$
#
#
#     $y_0 = l \cos(\theta_0)$ and $y(t) = l \cos(\theta_t)$ so $\Delta y = l(\cos\theta - \cos\theta_0)$
#
#   $\rightarrow \frac{d \theta}{dt} = \frac{\sqrt{2g l(\cos\theta - \cos\theta_0)}}{l}$
#
#   flipping the expression and solving for $dt$ gives:
#
#    $dt = \frac{l d \theta}{\sqrt{2g l(\cos\theta - \cos\theta_0)}}$ or $T = 4 \sqrt{\frac{l}{2g}} \int_0^{\theta_0}{\frac{d \theta}{\sqrt{\cos\theta - \cos\theta_0}}}$
#
# - If only you could integrate this, you could figure out a period and determine the number of periods in 10 minutes...
# - Ahh! You can integrate it numerically in python!
#
# 1. Set up a function `my_integrand` which takes in $l$, $g$, the starting angle of the pendulum $\theta_0 = 60^{\circ}$, the current angle of the pendulum $\theta$, and a angular step of $d \theta = 0.0001$ radians and returns $dt$ in seconds.
#
#    *HINT: Don't forget python always expects radians for trig functions!*
# 3. Call your function to find the precise time of a single period of the pendulum, $T$ using $l = 3.45$ m and $g = 9.8 \mathrm{\frac{m}{s^2}}$ you can use a Riemann sum but adjust your step size so that the results converge for the 3rd significant digit.
# 4. Check your Riemann sum with scipy.integrate.quad also check against the standard period of a pendulum assuming small angle oscillations.
# 5. How many periods passed in 10 minutes? Call this number $N$.
# 6. Round $N$ to the nearest whole number. Take the second digit in the number and append it to your code.

# %% [markdown]
# ## Escape the room!
#
# You have the 8 digits that you need to exit the room! You run to the key pad and enter the code. Did it work? Open the pdf ***keycodeV2.pdf*** using the 8 digits you got (no spaces or commas in between).

# %% [markdown]
# ## The Virus!?!
#
# You run around the cave and see the server with a clock counting down to release the homework virus! You need *another* password to get in. *Did you find it??* Enter it in a markdown cell below. You quickly open a terminal and access its main code. Dr. Monster was not that clever after all....You delete the running program and stop the flood of homework over the break!

# %% [markdown]
# # Have a great break! I hope you enjoyed this class!

# %% [markdown]
# Paste the portion of your log for this assignment here:

# %% [markdown]
# Save your notebook and upload it as your final project sumbission.
